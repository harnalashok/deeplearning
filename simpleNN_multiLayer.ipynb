# %% [markdown]
# <a href="https://colab.research.google.com/github/harnalashok/deeplearning/blob/main/simpleNN_multiLayer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Last amended: 2nd June, 2023
# Ref: https://www.kaggle.com/code/harnalashok/exercise-deep-neural-networks/edit

# %%
# 1.0 Call libraries
import pandas as pd
import numpy as np
from  pathlib import Path

# 1.0.1
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
# 1.1 Display multiple commands output from a cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# 2.0
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# 2.1 Where is our data file:
pathToFolder = "/gdrive/MyDrive/Colab_data_files/deeplearning"

# %%
# 2.2 Full file path:
path = Path(pathToFolder) / "concrete.csv"

# %%
# 3.0 Read data
data = pd.read_csv(path)
data.head()
# Out:
#    Cement  BlastFurnaceSlag  FlyAsh  Water  Superplasticizer  CoarseAggregate  \
# 0   540.0               0.0     0.0  162.0               2.5           1040.0
# 1   540.0               0.0     0.0  162.0               2.5           1055.0
# 2   332.5             142.5     0.0  228.0               0.0            932.0
# 3   332.5             142.5     0.0  228.0               0.0            932.0
# 4   198.6             132.4     0.0  192.0               0.0            978.4
#
#    FineAggregate  Age  CompressiveStrength
# 0          676.0   28                79.99
# 1          676.0   28                61.89
# 2          594.0  270                40.27
# 3          594.0  365                41.05
# 4          825.5  360                44.30

# %%
# 3.1
data.shape   # (1030, 9)
print("\n=====\n")
data.dtypes
# Out:
# (1030, 9)
# =====
# Cement                 float64
# BlastFurnaceSlag       float64
# FlyAsh                 float64
# Water                  float64
# Superplasticizer       float64
# CoarseAggregate        float64
# FineAggregate          float64
# Age                      int64
# CompressiveStrength    float64
# dtype: object

# %%
# 3.2 Get target and predictors:
y = data.pop("CompressiveStrength")
X = data

# %%
# 4.0 Build model:

model = tf.keras.Sequential()

# %%
# 4.0.1

model.add(layers.Input(shape = (8,) ))

# %%
# 4.0.2
model.add(layers.Dense(32, activation = 'relu'))
model.add(layers.Dense(32, activation='relu'))

# %%
# 4.0.4

model.add(layers.Dense(1))

# %%
# 4.1 Compile:

model.compile( loss = "mae")

# %%
# 4.2 Train:

model.fit(X,y, epochs = 300 )

# %%
# 5.0 Predict
pred = model.predict(X)
pred
# Out:
# 33/33 [==============================] - 0s 3ms/step

# %% [markdown]
# <b>Your turn:</b><br>
# Create another deeper NN as follows and set epochs to 300:<br>
# <code>
# model.add(layers.Dense(512, activation = 'relu'))<br>
# model.add(layers.Dense(512, activation='relu'))<br>
# model.add(layers.Dense(64, activation='relu'))</code>

# %%
######### --------Done ---------------
